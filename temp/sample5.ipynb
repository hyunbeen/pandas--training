# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import pandas

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\app\\pandas_workspace\\temp'

# %%
df = pandas.read_csv('../doit_pandas/data/gapminder.tsv', sep='\t')

# %%
global_yearly_life_expectancy = df.groupby('year')['lifeExp'].mean() 
print(global_yearly_life_expectancy)
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
global_yearly_life_expectancy.plot()

# %%
import pandas
df = pandas.read_csv('../doit_pandas/data/gapminder.tsv', sep='\t')
global_yearly_life_expectancy = df.groupby('year')['pop'].sum()
global_yearly_life_expectancy.plot()

# %%
pop = df['pop']
pop.plot()

# %%
pop = df['year']
pop.plot()

# %%
df = df['gpdPercap'].dropna()
gdp = df.sort_values(by=['gdpPercap'],inplace=True)[["gdpPercap"]].head(20)
gdp
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\app\python35\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gpdPercap'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-e908f006e7ae> in <module>
# ----> 1 df = df['gpdPercap'].dropna()
#
# ...

# %%
pop.plot()
